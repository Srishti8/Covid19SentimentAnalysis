# %%
import json
import pandas as pd
import numpy as np # linear algebra
import os
import re
import emoji
import string
import nltk

# %%
def load_jsonl(input_path) -> list:
    """
    Read list of objects from a JSON lines file.
    """
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line.rstrip('\n|\r')))
    print('Loaded {} records from {}'.format(len(data), input_path))
    return data

# %%
webpage_data = load_jsonl('data/trainingData/coronavirus-tweet-id-2020-06-01-00.jsonl')
db_data = []
db_cols = ['created_at', 'full_text', 'lang']
for d in webpage_data:
    db_data.append([])
    for col in db_cols:
        db_data[-1].append(d.get(col, float('nan')))
        
df = pd.DataFrame(db_data, columns=db_cols)
# Out:
# Loaded 36614 records from data/trainingData/coronavirus-tweet-id-2020-06-01-00.jsonl

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang
# 0  RT @LissomeLight: Oh my god these people reall...   en
# 1  RT @costareports: To some of the senators, Tru...   en
# 2  RT @AngrierWHStaff: The venn diagram of the pe...   en
# 3  RT @ArashKolahi: This country was infinity mor...   en
# 4              I SCREAMED 😂😂 https://t.co/CuIPpcFTTr   en

# %%
df.describe()
# Out:
#                             created_at  \
# count                            36614
# unique                             837
# top     Mon Jun 01 00:00:00 +0000 2020
# freq                                72
#
#                                                 full_text   lang
# count                                               36614  36614
# unique                                              16924     47
# top     RT @HelpfulKraken: They can't give you money t...     en
# freq                                                 1663  25334

# %%
def missing_value_of_data(data):
    total=data.isnull().sum().sort_values(ascending=False)
    percentage=round(total/data.shape[0]*100,2)
    return pd.concat([total,percentage],axis=1,keys=['Total','Percentage'])

# %%
missing_value_of_data(df)
# Out:
#             Total  Percentage
# lang            0         0.0
# full_text       0         0.0
# created_at      0         0.0

# %%
def count_values_in_column(data,feature):
    total=data.loc[:,feature].value_counts(dropna=False)
    percentage=round(data.loc[:,feature].value_counts(dropna=False,normalize=True)*100,2)
    return pd.concat([total,percentage],axis=1,keys=['Total','Percentage'])

# %%
count_values_in_column(df,'full_text')
# Out:
#                                                     Total  Percentage
# RT @HelpfulKraken: They can't give you money to...   1663        4.54
# RT @LEXartistes: Attending protests is not for ...    816        2.23
# RT @kissychalamets: la is closing covid-19 test...    566        1.55
# RT @brs2167: She got a walker. Can barely raise...    520        1.42
# RT @trythefish: Huntington Beach 2 weeks ago: P...    457        1.25
# ...                                                   ...         ...
# RT @Antena2RCN: Colombia se acerca a los 30mil ...      1        0.00
# RT @Lenin: ¡Las decisiones que tomamos son resp...      1        0.00
# RT @critlegthinking: ... featuring, inter alia,...      1        0.00
# What happened to the 60s,70s peaceful protester...      1        0.00
# 🇧🇷 Total de casos no Brasil: \nCasos confirmado...      1        0.00
#
# [16924 rows x 2 columns]

# %%
def unique_values_in_column(data,feature):
    unique_val=pd.Series(data.loc[:,feature].unique())
    return pd.concat([unique_val],axis=1,keys=['Unique Values'])

# %%
unique_values_in_column(df,'full_text')
# Out:
#                                            Unique Values
# 0      RT @LissomeLight: Oh my god these people reall...
# 1      RT @costareports: To some of the senators, Tru...
# 2      RT @AngrierWHStaff: The venn diagram of the pe...
# 3      RT @ArashKolahi: This country was infinity mor...
# 4                  I SCREAMED 😂😂 https://t.co/CuIPpcFTTr
# ...                                                  ...
# 16919  “The lesson from this disaster is that the leg...
# 16920  RT @Debora_D_Diniz: Ministra Damares faz chaco...
# 16921  interesting how just last week we were calling...
# 16922  Por um momento geral esqueceu do covid, fogo n...
# 16923  .@amyklobuchar has been on the ground in Minne...
#
# [16924 rows x 1 columns]

# %%
def duplicated_values_data(data):
    dup=[]
    columns=data.columns
    for i in data.columns:
        dup.append(sum(data[i].duplicated()))
    return pd.concat([pd.Series(columns),pd.Series(dup)],axis=1,keys=['Columns','Duplicate count'])

# %%
duplicated_values_data(df)
# Out:
#       Columns  Duplicate count
# 0  created_at            35777
# 1   full_text            19690
# 2        lang            36567

# %% [markdown]
# ## URL

# %%
 def find_url(string): 
    text = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+',string)
    return "".join(text) # converting return value from list to string

# %%
df['url']=df['full_text'].apply(lambda x:find_url(x))

# %%
df.head()
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  RT @LissomeLight: Oh my god these people reall...   en
# 1  RT @costareports: To some of the senators, Tru...   en
# 2  RT @AngrierWHStaff: The venn diagram of the pe...   en
# 3  RT @ArashKolahi: This country was infinity mor...   en
# 4              I SCREAMED 😂😂 https://t.co/CuIPpcFTTr   en
#
#                        url
# 0
# 1
# 2
# 3
# 4  https://t.co/CuIPpcFTTr

# %% [markdown]
# ## Emoticon

# %%
def find_emoji(text):
    emo_text=emoji.demojize(text)
    line=re.findall(r'\:(.*?)\:',emo_text)
    return line

# %%
df['emoji']=df['full_text'].apply(lambda x: find_emoji(x))

# %%
df.head()
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  RT @LissomeLight: Oh my god these people reall...   en
# 1  RT @costareports: To some of the senators, Tru...   en
# 2  RT @AngrierWHStaff: The venn diagram of the pe...   en
# 3  RT @ArashKolahi: This country was infinity mor...   en
# 4              I SCREAMED 😂😂 https://t.co/CuIPpcFTTr   en
#
#                        url                                             emoji
# 0                                                                         []
# 1                                                                         []
# 2                                                                         []
# 3                                                                         []
# 4  https://t.co/CuIPpcFTTr  [face_with_tears_of_joy, face_with_tears_of_joy]

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
df['full_text']=df['full_text'].apply(lambda x: remove_emoji(x))

# %% [markdown]
# ## Email

# %%
def find_email(text):
    line = re.findall(r'[\w\.-]+@[\w\.-]+',str(text))
    return ",".join(line)

# %%
df['email']=df['full_text'].apply(lambda x: find_email(x))

# %%
df.head()
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  RT @LissomeLight: Oh my god these people reall...   en
# 1  RT @costareports: To some of the senators, Tru...   en
# 2  RT @AngrierWHStaff: The venn diagram of the pe...   en
# 3  RT @ArashKolahi: This country was infinity mor...   en
# 4                I SCREAMED  https://t.co/CuIPpcFTTr   en
#
#                        url                                             emoji  \
# 0                                                                         []
# 1                                                                         []
# 2                                                                         []
# 3                                                                         []
# 4  https://t.co/CuIPpcFTTr  [face_with_tears_of_joy, face_with_tears_of_joy]
#
#   email
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Hashtags

# %%
def find_hash(text):
    line=re.findall(r'(?<=#)\w+',text)
    return " ".join(line)

# %%
df['hash']=df['full_text'].apply(lambda x: find_hash(x))
df.head()
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  RT @LissomeLight: Oh my god these people reall...   en
# 1  RT @costareports: To some of the senators, Tru...   en
# 2  RT @AngrierWHStaff: The venn diagram of the pe...   en
# 3  RT @ArashKolahi: This country was infinity mor...   en
# 4                I SCREAMED  https://t.co/CuIPpcFTTr   en
#
#                        url                                             emoji  \
# 0                                                                         []
# 1                                                                         []
# 2                                                                         []
# 3                                                                         []
# 4  https://t.co/CuIPpcFTTr  [face_with_tears_of_joy, face_with_tears_of_joy]
#
#   email hash
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Mentions

# %%
def find_at(text):
    line=re.findall(r'(?<=@)\w+',text)
    return " ".join(line)

# %%
df['at_mention']=df['full_text'].apply(lambda x: find_at(x))

# %%
df.head()
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  RT @LissomeLight: Oh my god these people reall...   en
# 1  RT @costareports: To some of the senators, Tru...   en
# 2  RT @AngrierWHStaff: The venn diagram of the pe...   en
# 3  RT @ArashKolahi: This country was infinity mor...   en
# 4                I SCREAMED  https://t.co/CuIPpcFTTr   en
#
#                        url                                             emoji  \
# 0                                                                         []
# 1                                                                         []
# 2                                                                         []
# 3                                                                         []
# 4  https://t.co/CuIPpcFTTr  [face_with_tears_of_joy, face_with_tears_of_joy]
#
#   email hash      at_mention
# 0               LissomeLight
# 1               costareports
# 2             AngrierWHStaff
# 3                ArashKolahi
# 4

# %% [markdown]
# ## Cleaning the corpus

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub(r'(?<=@)\w+', '', text)
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df['full_text'] = df['full_text'].apply(lambda x:clean_text(x))

# %%
df.head()
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  rt  oh my god these people really went from “m...   en
# 1  rt  to some of the senators trump seemed obses...   en
# 2  rt  the venn diagram of the people saying “jus...   en
# 3  rt  this country was infinity more prepared to...   en
# 4                                       i screamed     en
#
#                        url                                             emoji  \
# 0                                                                         []
# 1                                                                         []
# 2                                                                         []
# 3                                                                         []
# 4  https://t.co/CuIPpcFTTr  [face_with_tears_of_joy, face_with_tears_of_joy]
#
#   email hash      at_mention
# 0               LissomeLight
# 1               costareports
# 2             AngrierWHStaff
# 3                ArashKolahi
# 4

# %%
df['full_text'] = df['full_text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))

# %%
df.head()
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  these people really went from “making stay hom...   en
# 1  some senators trump seemed obsessed with savin...   en
# 2  venn diagram people saying “just comply with p...   en
# 3  this country infinity more prepared against pe...   en
# 4                                           screamed   en
#
#                        url                                             emoji  \
# 0                                                                         []
# 1                                                                         []
# 2                                                                         []
# 3                                                                         []
# 4  https://t.co/CuIPpcFTTr  [face_with_tears_of_joy, face_with_tears_of_joy]
#
#   email hash      at_mention
# 0               LissomeLight
# 1               costareports
# 2             AngrierWHStaff
# 3                ArashKolahi
# 4

# %% [markdown]
# ## tokenization

# %%
def tokenization(text):
    text = re.split('\W+', text)
    return text

df['tokenized'] = df['full_text'].apply(lambda x: tokenization(x.lower()))
df.head()
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  these people really went from “making stay hom...   en
# 1  some senators trump seemed obsessed with savin...   en
# 2  venn diagram people saying “just comply with p...   en
# 3  this country infinity more prepared against pe...   en
# 4                                           screamed   en
#
#                        url                                             emoji  \
# 0                                                                         []
# 1                                                                         []
# 2                                                                         []
# 3                                                                         []
# 4  https://t.co/CuIPpcFTTr  [face_with_tears_of_joy, face_with_tears_of_joy]
#
#   email hash      at_mention  \
# 0               LissomeLight
# 1               costareports
# 2             AngrierWHStaff
# 3                ArashKolahi
# 4
#
#                                            tokenized
# 0  [these, people, really, went, from, making, st...
# 1  [some, senators, trump, seemed, obsessed, with...
# 2  [venn, diagram, people, saying, just, comply, ...
# 3  [this, country, infinity, more, prepared, agai...
# 4                                         [screamed]

# %% [markdown]
# ## remove stop words

# %%
nltk.download('stopwords')
stopword = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\srjhanwa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    
df['stopwords_removed'] = df['tokenized'].apply(lambda x: remove_stopwords(x))
df.head(10)
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
# 5  Mon Jun 01 00:00:00 +0000 2020
# 6  Mon Jun 01 00:00:00 +0000 2020
# 7  Mon Jun 01 00:00:00 +0000 2020
# 8  Mon Jun 01 00:00:00 +0000 2020
# 9  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  these people really went from “making stay hom...   en
# 1  some senators trump seemed obsessed with savin...   en
# 2  venn diagram people saying “just comply with p...   en
# 3  this country infinity more prepared against pe...   en
# 4                                           screamed   en
# 5  continua envergonhando história diplomacia bra...   pt
# 6   icymi clintons have killed more than coronavirus   en
# 7  they cant give money survive pandemic they can...   en
# 8  unique like purple within purple state watch w...   en
# 9  covid socialdistancing rulesdon’t stand close ...   en
#
#                        url                                             emoji  \
# 0                                                                         []
# 1                                                                         []
# 2                                                                         []
# 3                                                                         []
# 4  https://t.co/CuIPpcFTTr  [face_with_tears_of_joy, face_with_tears_of_joy]
# 5  https://t.co/2LdPbIpwMs                                                []
# 6  https://t.co/00dDDRIs4o                                                []
# 7                                                                         []
# 8                                                                         []
# 9                                                                         []
#
#   email hash      at_mention  \
# 0               LissomeLight
# 1               costareports
# 2             AngrierWHStaff
# 3                ArashKolahi
# 4
# 5
# 6                  blaze0497
# 7              HelpfulKraken
# 8                KcNightfire
# 9                  RichLowry
#
#                                            tokenized  \
# 0  [these, people, really, went, from, making, st...
# 1  [some, senators, trump, seemed, obsessed, with...
# 2  [venn, diagram, people, saying, just, comply, ...
# 3  [this, country, infinity, more, prepared, agai...
# 4                                         [screamed]
# 5  [continua, envergonhando, história, diplomacia...
# 6  [icymi, clintons, have, killed, more, than, co...
# 7  [they, cant, give, money, survive, pandemic, t...
# 8  [unique, like, purple, within, purple, state, ...
# 9  [covid, socialdistancing, rulesdon, t, stand, ...
#
#                                    stopwords_removed
# 0  [people, really, went, making, stay, home, tyr...
# 1  [senators, trump, seemed, obsessed, saving, li...
# 2  [venn, diagram, people, saying, comply, police...
# 3  [country, infinity, prepared, people, defend, ...
# 4                                         [screamed]
# 5  [continua, envergonhando, história, diplomacia...
# 6             [icymi, clintons, killed, coronavirus]
# 7  [cant, give, money, survive, pandemic, cant, f...
# 8  [unique, like, purple, within, purple, state, ...
# 9  [covid, socialdistancing, rulesdon, stand, clo...

# %% [markdown]
# ## Stemming and Lemmatization

# %%
ps = nltk.PorterStemmer()

def stemming(text):
    text = [ps.stem(word) for word in text]
    return text

df['stemmed'] = df['stopwords_removed'].apply(lambda x: stemming(x))
df.head()
# Out:
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  these people really went from “making stay hom...   en
# 1  some senators trump seemed obsessed with savin...   en
# 2  venn diagram people saying “just comply with p...   en
# 3  this country infinity more prepared against pe...   en
# 4                                           screamed   en
#
#                        url                                             emoji  \
# 0                                                                         []
# 1                                                                         []
# 2                                                                         []
# 3                                                                         []
# 4  https://t.co/CuIPpcFTTr  [face_with_tears_of_joy, face_with_tears_of_joy]
#
#   email hash      at_mention  \
# 0               LissomeLight
# 1               costareports
# 2             AngrierWHStaff
# 3                ArashKolahi
# 4
#
#                                            tokenized  \
# 0  [these, people, really, went, from, making, st...
# 1  [some, senators, trump, seemed, obsessed, with...
# 2  [venn, diagram, people, saying, just, comply, ...
# 3  [this, country, infinity, more, prepared, agai...
# 4                                         [screamed]
#
#                                    stopwords_removed  \
# 0  [people, really, went, making, stay, home, tyr...
# 1  [senators, trump, seemed, obsessed, saving, li...
# 2  [venn, diagram, people, saying, comply, police...
# 3  [country, infinity, prepared, people, defend, ...
# 4                                         [screamed]
#
#                                              stemmed
# 0  [peopl, realli, went, make, stay, home, tyrann...
# 1  [senat, trump, seem, obsess, save, live, appea...
# 2  [venn, diagram, peopl, say, compli, polic, sta...
# 3  [countri, infin, prepar, peopl, defend, peopl,...
# 4                                           [scream]

# %%
nltk.download('wordnet')
wn = nltk.WordNetLemmatizer()

def lemmatizer(text):
    text = [wn.lemmatize(word) for word in text]
    return text

df['lemmatized'] = df['stemmed'].apply(lambda x: lemmatizer(x))
df.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\srjhanwa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
#                        created_at  \
# 0  Mon Jun 01 00:00:00 +0000 2020
# 1  Mon Jun 01 00:00:00 +0000 2020
# 2  Mon Jun 01 00:00:00 +0000 2020
# 3  Mon Jun 01 00:00:00 +0000 2020
# 4  Mon Jun 01 00:00:00 +0000 2020
#
#                                            full_text lang  \
# 0  these people really went from “making stay hom...   en
# 1  some senators trump seemed obsessed with savin...   en
# 2  venn diagram people saying “just comply with p...   en
# 3  this country infinity more prepared against pe...   en
# 4                                           screamed   en
#
#                        url                                             emoji  \
# 0                                                                         []
# 1                                                                         []
# 2                                                                         []
# 3                                                                         []
# 4  https://t.co/CuIPpcFTTr  [face_with_tears_of_joy, face_with_tears_of_joy]
#
#   email hash      at_mention  \
# 0               LissomeLight
# 1               costareports
# 2             AngrierWHStaff
# 3                ArashKolahi
# 4
#
#                                            tokenized  \
# 0  [these, people, really, went, from, making, st...
# 1  [some, senators, trump, seemed, obsessed, with...
# 2  [venn, diagram, people, saying, just, comply, ...
# 3  [this, country, infinity, more, prepared, agai...
# 4                                         [screamed]
#
#                                    stopwords_removed  \
# 0  [people, really, went, making, stay, home, tyr...
# 1  [senators, trump, seemed, obsessed, saving, li...
# 2  [venn, diagram, people, saying, comply, police...
# 3  [country, infinity, prepared, people, defend, ...
# 4                                         [screamed]
#
#                                              stemmed  \
# 0  [peopl, realli, went, make, stay, home, tyrann...
# 1  [senat, trump, seem, obsess, save, live, appea...
# 2  [venn, diagram, peopl, say, compli, polic, sta...
# 3  [countri, infin, prepar, peopl, defend, peopl,...
# 4                                           [scream]
#
#                                           lemmatized
# 0  [peopl, realli, went, make, stay, home, tyrann...
# 1  [senat, trump, seem, ob, save, live, appear, p...
# 2  [venn, diagram, peopl, say, compli, polic, sta...
# 3  [countri, infin, prepar, peopl, defend, peopl,...
# 4                                           [scream]
